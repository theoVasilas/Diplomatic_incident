# %%
from dataset import *
from HE_functions import *
from help_functions import *
from models import *
from task import *
from models import *

# %% [markdown]
# # DONE

# %% [markdown]
# ## find parameters for CKKS key gen and Opperation

# %%
model = BiggerModel()
csv_configs = load_csv_as_dicts("Configs/test_conf_2.csv")

accep_config = find_acceptable_params_for_CKKS(model, csv_configs)
# Out:
# with degree: 2048 and coeff: [20, 20, 14]
# Performed homomorphic multiplication by 2.
# Performed homomorphic Addition.
# Performed homomorphic Addition.
# Data saved to 'valid_config_new.csv'

# %% [markdown]
# ## test Pressision and Time of Keys

# %%
model = BiggerModel()
valid_config = load_csv_as_dicts("Configs/test_conf_2.csv")

results = test_pressiosion_of_keys(model, valid_config)
# Out:
# with degree: 2048 and coeff: [20, 20, 14]
# multiplication_by2 : error 1.0623759546092326 time spend 0.0018339157104492188
# Addition_weight_2 : error 0.05717310091203842 time spend 0.0015730857849121094
# Add_encrp_weights : error 0.05806523747291353 time spend 0.0015463829040527344
# sum diff 1.1776142929941846 sum time 0.0049533843994140625
# Data saved to 'config_stats.csv'

# %%
plot_config_stats(file_nemae = "Results/config_stats.csv")

# %% [markdown]
# ## Size of ciphertext and keys

# %%
model = BiggerModel()
valid_config = load_csv_as_dicts("Configs/valid_config.csv")

size_of_ciphertext, size_benchmarks = mesure_size_chifertext(model, valid_config)

plot_ckks_size("Results/ciphertext_benchmarks.csv")

# %% [markdown]
# # WORKING ON
